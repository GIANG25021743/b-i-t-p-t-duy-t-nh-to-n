# %%
# bài tập 1
so_nhap_vao=input("nhập vào số nguyên:")
so_nhap_vao.strip()
length=len(so_nhap_vao)
s=""
for i in range(length):
   s+= so_nhap_vao[length-1-i]
print(s)
# Out:
# nhập vào số nguyên:1
# 1

# %%
# bài tập 2
a,b=map(int, input().split())
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# 213 4234
# 4234 213

# %%
# bài tập 3
a=int(input("nhập 1 số nguyên:"))
check= True if a&(a-1)==0 else False
print(check)
# Out:
# nhập 1 số nguyên:32
# True

# %%
# bài tập 4
a,b=map(int, input().split())
print(int(a/b))
# Out:
# 2323 45
# 51

# %%
# bài tập 5
a,b=map(int, input().split())
print(int(round(a/b,0)))
# Out:
# 432 42
# 10

# %%
# bài tập 6
a=int(input("nhập vào một số dương:"))
print( "even" if a%2==0 else "odd" )
# Out:
# nhập vào một số dương:45
# odd

# %%
# bài tập 7
a,b=map(int, input().split())
print("yes" if a<0 and b<0 else "no")
# Out:
# -2 4
# no

# %%
# bài tập 8
# bài tập 5
print( True if a>b else False )
# Out:
# toi giang
# True

# %%
# bài tập 9
a,b,c=map(int, input().split())
def  check(a,b,c):
  if(a<b+c and b<a+c and c<b+a):
    return "yes"
  return "no"
print(check(a,b,c))
# Out:
# 3 6 2
# no

# %%
# bài tập 10
a,b,c,d=map(int, input().split())
def max(a,b):
  if(a>b):
    return a
  return b;
print(max(max(a,b),max(c,d)))
# Out:
# -1 -1 -1 -1
# -1

# %%
# bài tập 11
a,b,c=map(int, input().split())
def  check(a,b,c):
  if(a<b+c and b<a+c and c<b+a):
    if(a==b or a==c ):
      if(b==c):
        return "tam giác đều"
      return "tam giác cân"
    return "tam giác thường"
  return "không phải tam giác"
print(check(a,b,c))
# Out:
# 3 3 9
# không phải tam giác

# %%
# bài tập 12
a=int(input(" năm :"))
print("yes" if a%400==0 or (a%4==0 and a%100!=0) else "no")
# Out:
#  năm :2024
# yes

# %%
# bài tập 13
so_dien=int(input("số điện:"))
if so_dien<=50:
  print(so_dien*1500)
elif so_dien<=100:
  print(50*1500+(so_dien-50)*2000)
else:
  print(50*1500 + 50*2000 +(so_dien-100)*3000)
# Out:
# số điện:43
# 64500

# %%
# bài tập 14
# Nhập hai số thực a và b
a = float(input("Nhập hệ số a: "))
b = float(input("Nhập hệ số b: "))

# Giải phương trình ax + b = 0
if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    x = -b / a
    print("Nghiệm của phương trình là:", round(x, 2))
# Out:
# Nhập hệ số a: 4
# Nhập hệ số b: 6
# Nghiệm của phương trình là: -1.5

# %%
# bài tập 15
diem=float(input("nhập điểm:"))
if diem>=8:
  print("GIỎI")
elif diem>=6.5:
  print("KHÁ")
elif diem>=5:
  print("TRUNG BÌNH")
else:
  print("YẾU")
# Out:
# nhập điểm:10
# GIỎI

# %%
# bài tập 16
a=float(input("nhập một số nguyên:"))
b=a//1
if(b==a):
  print(a," ")
  print(a," ")
  print(a," ")
elif(a>0):
  print(b+1," ")
  print(b," ")
  print(b +1 if (a-b)>=0.5 else b," ")
else:
  print(b +1," ")
  """vì // với số âm sẽ lấy về phía vô cùng"""
  print(b," ")
  print(b-1 if (b-a)>=0.5 else b," ")
# Out:
# nhập một số nguyên:7.4
# 8.0
# 7.0
# 7.0
